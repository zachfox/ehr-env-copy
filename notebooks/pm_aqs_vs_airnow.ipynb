# %%
# %matplotlib notebook 

import os

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

# %%
base_dir = '..'
data_path = os.path.join(base_dir,'data','raw','alabama_pm_aqs.csv')

# %%
data = pd.read_csv(data_path)

# %%
data.columns
# Out:
# Index(['Date', 'Source', 'Site ID', 'POC', 'Daily Mean PM2.5 Concentration',
#        'UNITS', 'DAILY_AQI_VALUE', 'Site Name', 'DAILY_OBS_COUNT',
#        'PERCENT_COMPLETE', 'AQS_PARAMETER_CODE', 'AQS_PARAMETER_DESC',
#        'CBSA_CODE', 'CBSA_NAME', 'STATE_CODE', 'STATE', 'COUNTY_CODE',
#        'COUNTY', 'SITE_LATITUDE', 'SITE_LONGITUDE'],
#       dtype='object')

# %%
airnow_data = data[data['Source']=='AirNow']
aqs_data = data[data['Source']=='AQS']

# %%
f,ax = plt.subplots(1,2,figsize=(5,2))
ax[0].hist(airnow_data['Daily Mean PM2.5 Concentration'].to_numpy())
ax[1].hist(aqs_data['Daily Mean PM2.5 Concentration'].to_numpy(),bins=100)
ax[1].set_xlim([0,30])
ax[0].set_xlim([0,30])
f.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="499.9999925494195">

# %%
x = [1,2]; y=[3,4]
list(zip(x,y))
# Out:
# [(1, 3), (2, 4)]
