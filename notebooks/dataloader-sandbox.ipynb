# %%
# %matplotlib notebook 
import matplotlib.pyplot as plt


import sys
sys.path.append('../src/models')

from importlib import reload
import dataloaders as dl
import dataloaders_new as dln

# %%
reload(dl)

data_config = {'data_path': '../data/processed/processed_pm25_gridmet.csv',
               'split_path': '../data/processed/split_h3.csv',
               'num_sensors': 8, 
               'space_bands': 12, 
               'num_queries': 2,
               'seed': 42,
               'split': 'train'}

loader = dl.SenseiverLoaderSimple(data_config)

for i in range(len(loader)):
    a,b,c = loader.__getitem__(i)
    if a.shape[0] != 8:
        print
        break
# Out:
# Index(['Date', 'Lat', 'Lon', 'Elevation', 'Conc', 'h3_08_x', 'Site_x', 'id',
#        'min_air_temperature_value', 'max_air_temperature_value',
#        'min_relative_humidity_value', 'max_relative_humidity_value',
#        'wind_speed_value', 'precipitation_amount_value', 'Split', 'Site_y',
#        'h3_08_y', 'h3'],
#       dtype='object')

# %%
for i in range(5):
    values, query_values, field_values = loader.__getitem__(0)
    f,ax = plt.subplots(figsize=(7,3.5))
    print(field_values)
    ax.scatter(loader.data['lon'][loader.tindex], loader.data['lat'][loader.tindex],s=5, c='gray')
    ax.scatter(loader.sensor_positions[:,1], loader.sensor_positions[:,0],s=17)
    ax.scatter(loader.query_positions[:,1], loader.query_positions[:,0],s=17)
    print(loader.sensor_positions.shape)
    ax.axis('off')
# Out:
# <img src="data:image/png;base64,..." width="700">
# tensor([[1.3838]])
# torch.Size([8, 3])
# <img src="data:image/png;base64,..." width="700">
# tensor([[1.0170]])
# torch.Size([8, 3])
# <img src="data:image/png;base64,..." width="700">
# tensor([[1.2355]])
# torch.Size([8, 3])
# <img src="data:image/png;base64,..." width="700">
# tensor([[1.0531]])
# torch.Size([8, 3])
# <img src="data:image/png;base64,..." width="700">
# tensor([[1.2695]])
# torch.Size([8, 3])

# %%
import pandas as pd
data = pd.read_csv('../data/processed/processed_pm25_gridmet_2013.csv')

# %%
data
# Out:
#           Date       Lat       Lon  Elevation  Conc            h3_08  \
# 0       734869  0.267449  0.760971   0.128205   7.3  884450cce5fffff
# 1       734869  0.326809  0.783508   0.058843   5.0  8844eab2a9fffff
# 2       734869  0.358321  0.763473   0.064924   5.1  8826494db7fffff
# 3       734869  0.348273  0.781707   0.057528   5.6  8844eb0993fffff
# 4       734869  0.342005  0.781460   0.061801   8.7  8844eb1b47fffff
# ...        ...       ...       ...        ...   ...              ...
# 107209  735233  0.412165  0.847649   0.056542   4.2  882a8a9667fffff
# 107210  735233  0.402749  0.887789   0.037147   8.2  882af62289fffff
# 107211  735233  0.566233  0.759757   0.037804  10.5  88274350b9fffff
# 107212  735233  0.535649  0.744123   0.032216  12.7  88275801d3fffff
# 107213  735233  0.561969  0.755403   0.052597   9.7  88275cb309fffff
#
#              Site                   id  min_air_temperature_value  \
# 0        10030010   2013-01-0110030010                   0.714749
# ...

# %%
f,ax = plt.subplots()
ax.hist(data["Conc"], bins=55)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (array([6.9190e+03, 2.9849e+04, 2.8706e+04, 1.8929e+04, 1.1131e+04,
#         5.5520e+03, 2.6440e+03, 1.2920e+03, 6.6000e+02, 4.2600e+02,
#         2.5700e+02, 2.2100e+02, 1.1100e+02, 1.0200e+02, 9.0000e+01,
#         5.9000e+01, 5.2000e+01, 4.5000e+01, 2.6000e+01, 2.6000e+01,
#         1.3000e+01, 1.2000e+01, 1.4000e+01, 9.0000e+00, 7.0000e+00,
#         3.0000e+00, 7.0000e+00, 8.0000e+00, 4.0000e+00, 5.0000e+00,
#         7.0000e+00, 2.0000e+00, 4.0000e+00, 2.0000e+00, 3.0000e+00,
#         2.0000e+00, 2.0000e+00, 2.0000e+00, 1.0000e+00, 3.0000e+00,
#         4.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00]),
#  array([  0.        ,   3.04181818,   6.08363636,   9.12545455,
#          12.16727273,  15.20909091,  18.25090909,  21.29272727,
# ...

# %%
scatter_cols = data.columns[8:]
ncol = len(scatter_cols)
f,ax = plt.subplots(ncol,ncol, figsize=(12,10))
for i in range(ncol):
    for j in range(ncol):
        ax[i,j].scatter(data[scatter_cols[i]],data[scatter_cols[j]],s=3)
# Out:
# <img src="data:image/png;base64,..." width="1200">

# %%
data["Conc"].mean()
# Out:
# 9.06644281530397

# %%
# !conda env list
# Out:
# # conda environments:
# #
# base                     /Users/z6f/anaconda3
# causal                   /Users/z6f/anaconda3/envs/causal
# causal_zf             *  /Users/z6f/anaconda3/envs/causal_zf
# hydra                    /Users/z6f/anaconda3/envs/hydra
# neuraldecipher           /Users/z6f/anaconda3/envs/neuraldecipher
# rc                       /Users/z6f/anaconda3/envs/rc
# rdkit_env                /Users/z6f/anaconda3/envs/rdkit_env
# torch                    /Users/z6f/anaconda3/envs/torch
#                          /Users/z6f/opt/anaconda3
#                          /Users/z6f/opt/anaconda3/envs/bert
#                          /Users/z6f/opt/anaconda3/envs/causal
#                          /Users/z6f/opt/anaconda3/envs/cellpose
#                          /Users/z6f/opt/anaconda3/envs/dnabert
#                          /Users/z6f/opt/anaconda3/envs/fresco
#                          /Users/z6f/opt/anaconda3/envs/omnipose
# ...

# %%
reload(dl)

data_config = {'data_path': '../data/processed/processed_pm25_gridmet_None.parquet',
               'split_path': '../data/processed/split_h3.csv',
               'num_sensors': 8, 
               'space_bands': 12, 
               'num_queries': 2,
               'seed': 42,
               'split': 'train',
               'nlags': 5,
                'locality': .01}

train_loader = dl.SenseiverLoaderSimple(data_config)
# val_loader = dl.SenseiverLoaderValidation(data_config)
# test_loader = dl.SenseiverLoaderTest(data_config)

# %%
train_loader.__getitem__(0)
all_nan = 0
for i in range(len(train_loader)):
    a,b,c = train_loader.__getitem__(i)
    aa = torch.isnan(a).sum()
    if aa>0:
        print(a,b,c)
    bb = torch.isnan(b).sum()
    if bb>0:
        print(a,b,c)
    cc = torch.isnan(c).sum()
    if cc>0:
        print(a,b,c)
    all_nan += aa+bb+cc

# %%
all_nan
# Out:
# tensor(0)

# %%
import torch
torch.isnan(torch.Tensor([torch.nan,1,torch.nan]))
# Out:
# tensor([ True, False,  True])

# %%
loader.data
# Out:
# {'min_air_temperature_value': tensor([0.6961, 0.5292, 0.5047,  ..., 0.6269, 0.6269, 0.5739]),
#  'max_air_temperature_value': tensor([0.6531, 0.5769, 0.5032,  ..., 0.6264, 0.6264, 0.5743]),
#  'min_relative_humidity_value': tensor([0.4324, 0.4555, 0.3023,  ..., 0.4474, 0.4474, 0.3564]),
#  'max_relative_humidity_value': tensor([0.9767, 0.7862, 0.9397,  ..., 1.0000, 1.0000, 0.8529]),
#  'wind_speed_value': tensor([0.2350, 0.4317, 0.2842,  ..., 0.1148, 0.1148, 0.1202]),
#  'precipitation_amount_value': tensor([0.0000, 0.0379, 0.0021,  ..., 0.0070, 0.0070, 0.0000]),
#  'lat': tensor([0.7913, 0.6187, 0.6895,  ..., 0.4830, 0.4830, 0.5903]),
#  'lon': tensor([0.6904, 0.5986, 0.7382,  ..., 0.4602, 0.4602, 0.6305]),
#  'elevation': tensor([0.1126, 0.0823, 0.0971,  ..., 0.0799, 0.0799, 0.0530]),
#  'log_target': tensor([0.3979, 0.7782, 0.8633,  ..., 0.7202, 0.7202, 1.0719]),
#  'time': tensor([731068., 730918., 730897.,  ..., 737770., 737770., 737714.]),
# ...

# %%
import polars as pl
data = pl.read_parquet("../data/processed/processed_pm25_gridmet_None.parquet")

# %%
data
# Out:
# shape: (3_075_945, 15)
# ┌────────┬──────────┬──────────┬───────────┬───┬────────────┬────────────┬────────────┬────────────┐
# │ Date   ┆ Lat      ┆ Lon      ┆ Elevation ┆ … ┆ min_relati ┆ max_relati ┆ wind_speed ┆ precipitat │
# │ ---    ┆ ---      ┆ ---      ┆ ---       ┆   ┆ ve_humidit ┆ ve_humidit ┆ _value     ┆ ion_amount │
# │ i64    ┆ f64      ┆ f64      ┆ f64       ┆   ┆ y_value    ┆ y_value    ┆ ---        ┆ _value     │
# │        ┆          ┆          ┆           ┆   ┆ ---        ┆ ---        ┆ f64        ┆ ---        │
# │        ┆          ┆          ┆           ┆   ┆ f64        ┆ f64        ┆            ┆ f64        │
# ╞════════╪══════════╪══════════╪═══════════╪═══╪════════════╪════════════╪════════════╪════════════╡
# │ 731068 ┆ 0.791299 ┆ 0.690366 ┆ 0.112557  ┆ … ┆ 0.432432   ┆ 0.97672    ┆ 0.234973   ┆ 0.0        │
# │ 730918 ┆ 0.618747 ┆ 0.598566 ┆ 0.0823    ┆ … ┆ 0.455455   ┆ 0.786243   ┆ 0.431694   ┆ 0.037891   │
# ...

# %%
import numpy as np

def count_negatives(x):
    return np.sum(x<=0)
data = data.with_columns(pl.col("lags_pm_prior").map_elements(count_negatives,return_dtype=float).alias("negative_count"))
# Out:
# thread 'polars-0' panicked at py-polars/src/map/series.rs:222:19:
# python function failed TypeError: sum() got an unexpected keyword argument 'axis'
# --- PyO3 is resuming a panic after fetching a PanicException from Python. ---
# Python stack trace below:
# thread 'polars-1' panicked at py-polars/src/map/series.rs:222:19:
# python function failed TypeError: sum() got an unexpected keyword argument 'axis'
# --- PyO3 is resuming a panic after fetching a PanicException from Python. ---
# Python stack trace below:
# thread 'polars-3' panicked at py-polars/src/map/series.rs:222:19:
# python function failed TypeError: sum() got an unexpected keyword argument 'axis'
# --- PyO3 is resuming a panic after fetching a PanicException from Python. ---
# Python stack trace below:
# thread 'polars-2' panicked at py-polars/src/map/series.rs:222:19:
# python function failed TypeError: sum() got an unexpected keyword argument 'axis'
# ...

# %%
f,ax = plt.subplots()
ax.hist(data['precipitation_amount_value'].to_list(),bins=55)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (array([2.785022e+06, 1.585980e+05, 6.700600e+04, 3.142500e+04,
#         1.514000e+04, 7.904000e+03, 4.267000e+03, 2.489000e+03,
#         1.455000e+03, 8.880000e+02, 5.700000e+02, 3.470000e+02,
#         2.480000e+02, 1.850000e+02, 1.310000e+02, 7.200000e+01,
#         4.800000e+01, 4.500000e+01, 3.000000e+01, 1.700000e+01,
#         1.200000e+01, 1.000000e+01, 8.000000e+00, 7.000000e+00,
#         3.000000e+00, 1.000000e+00, 3.000000e+00, 1.000000e+00,
#         2.000000e+00, 2.000000e+00, 3.000000e+00, 1.000000e+00,
#         1.000000e+00, 0.000000e+00, 1.000000e+00, 1.000000e+00,
#         0.000000e+00, 0.000000e+00, 1.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 0.000000e+00, 0.000000e+00,
#         0.000000e+00, 0.000000e+00, 1.000000e+00]),
# ...

# %%
dataset = pl.read_parquet(data_config['data_path'])    
splits = pl.read_csv(data_config['split_path'])
# join
dataset = dataset.join(splits, on="id", how="left")
# Out:
# /var/folders/tm/mw0_yxrx1419zt6ys2b7vd6x_klh1b/T/ipykernel_27433/2370506705.py:4: DeprecationWarning: The default coalesce behavior of left join will change to `False` in the next breaking release. Pass `coalesce=True` to keep the current behavior and silence this warning.
#   dataset = dataset.join(splits, on="id", how="left")

# %%
dataset.filter(pl.col("split")=="train")
# Out:
# ---------------------------------------------------------------------------
# ColumnNotFoundError                       Traceback (most recent call last)
# Cell In[108], line 1
# ----> 1 dataset.filter(pl.col("split")=="train")
#
# File ~/anaconda3/envs/causal_zf/lib/python3.9/site-packages/polars/dataframe/frame.py:4268, in DataFrame.filter(self, *predicates, **constraints)
#    4168 def filter(
#    4169     self,
#    4170     *predicates: (
#    (...)
#    4177     **constraints: Any,
#    4178 ) -> DataFrame:
#    4179     """
#    4180     Filter the rows in the DataFrame based on one or more predicate expressions.
#    4181
#    (...)
#    4266     └─────┴─────┴─────┘
#    4267     """
# -> 4268     return self.lazy().filter(*predicates, **constraints).collect(_eager=True)
#
# ...

# %%
f,ax = plt.subplots()
ax.hist(dataset.filter(pl.col("Split")=="train")["Date"])
ax.hist(dataset.filter(pl.col("Split")=="val")["Date"])
# Out:
# <img src="data:image/png;base64,..." width="640">
# (array([29788., 28332., 26731., 25491., 24768., 24065., 43908., 60126.,
#         77881., 79552.]),
#  array([730851. , 731544.9, 732238.8, 732932.7, 733626.6, 734320.5,
#         735014.4, 735708.3, 736402.2, 737096.1, 737790. ]),
#  <BarContainer object of 10 artists>)
